# %%
class No:
    def __init__(self, valor):
        self.valor = valor
        self.proximo = None

class ListaEncadeada:
    def __init__(self):
        self.inicio = None

    def inserir(self, valor):
        novo_no = No(valor)
        if self.inicio is None:
            self.inicio = novo_no
        else:
            atual = self.inicio
            while atual.proximo is not None:
                atual = atual.proximo
            atual.proximo = novo_no

    def contar(self):
        atual = self.inicio
        contador = 0
        
        while atual is not None:
            contador += 1
            atual = atual.proximo

        return contador

lista = ListaEncadeada()
lista.inserir(5)
lista.inserir(15)
lista.inserir(25)
lista.inserir (35)
lista.inserir (32)
lista.inserir (2)
lista.inserir (4232)
lista.inserir (43)

print(lista.contar())  # Saída esperada: 8
# Out:
# 8
